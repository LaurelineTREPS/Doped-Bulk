# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres
col = 1
colors = ['dimgray',"#7F00FF", 'dodgerblue', 'darkturquoise', 'mediumseagreen','olivedrab','goldenrod']
shift = 0.005

# Données
x = [[1, 0.87, 0.75, 0.625, 0.50, 0.375, 0.25]]
y = [[0.86746793, 0.51577546, 0.339986048, 0.209956991, 0-0.0025, 0.227680443, 0.306764331]]#Ni à 1.5V
y4 = [[0.177915428, 0.009819893, 0, 0.045069224, 0.009225958, 0.400544951, 0.64879483]] #Ni à 1.3V
yCu = [[0.0, 0.436149651313997, 0.378922594804919, 0.136319649164022, 0.0417427979835452]]
yCo = [[0.25092619391455173, 0.24174148236130577, 0.12925634572366107, 0.1484215499907009, 0+0.0025]]
yFe6 = [[0.404135141, 0.149226973, 0, 0.018403316, 0.016161895, 0.19863384, 0.3168983]]#Fe à 1.5V
yFe4 = [[0.081242437, 0, 0.034288765, 0.236946388, 0.401543959, 0.743423012, 1.025227747]]#Fe à 1.3V
yMn6 = [[0.558687052, 0.570064806, 0.199578329, 0.368367476, 0.450579315, 0.013072696, 0]]#Mn à 1.5V
yMn4 = [[0.036428485, 0.209456604, 0, 0.345059611, 0.589424307, 0.325721177, 0.480224911]]#Mn à 1.3V
yV6 = [[1.244806462, 0.497657874, 0.655371541, 0.158114288, 0, 0.01807654, 0.070943139]]#V à 1.5V
yV4 = [[0.588543512, 0, 0.31955577, 0.003704636, 0.018716595, 0.206817286, 0.432564718]]#V à 1.3V
yCr6 = [[0.484055715, 0.120465784, 0.170342598, 0.088059489, 0, 2.252706313, 1.443806729]]#Cr à 1.5V
yCr4 = [[0.180930071, 0, 0.220522695, 0.306883687, 0.396451853, 2.469068158, 1.783375659]]#Cr à 1.3V

text = [["100", "87.5", "75", "62.5", "50", "37.5", "25"]]

x_gap = 0.015
x_stretch = [[] for _ in range(col)]
y_stretch = [[] for _ in range(col)]
y4_stretch = [[] for _ in range(col)]
yCo_stretch = [[] for _ in range(col)]
yCu_stretch = [[] for _ in range(col)]
yFe6_stretch = [[] for _ in range(col)]
yFe4_stretch = [[] for _ in range(col)]
yMn6_stretch = [[] for _ in range(col)]
yMn4_stretch = [[] for _ in range(col)]
yV6_stretch = [[] for _ in range(col)]
yV4_stretch = [[] for _ in range(col)]
yCr6_stretch = [[] for _ in range(col)]
yCr4_stretch = [[] for _ in range(col)]

for i in range(col):
    for idx in range(len(y[i])):
        x_stretch[i].extend([(x[i][idx] - x_gap)*100, (x[i][idx] + x_gap)*100, None])
        y_stretch[i].extend([y[i][idx], y[i][idx], None])
        y4_stretch[i].extend([y4[i][idx], y4[i][idx], None])
        #yCo_stretch[i].extend([yCo[i][idx], yCo[i][idx], None])
        #yCu_stretch[i].extend([yCu[i][idx], yCu[i][idx], None])
        #yFe6_stretch[i].extend([yFe6[i][idx], yFe6[i][idx], None])
        #yFe4_stretch[i].extend([yFe4[i][idx], yFe4[i][idx], None])
        #yMn6_stretch[i].extend([yMn6[i][idx], yMn6[i][idx], None])
        #yMn4_stretch[i].extend([yMn4[i][idx], yMn4[i][idx], None])
        #yV6_stretch[i].extend([yV6[i][idx], yV6[i][idx], None])
        #yV4_stretch[i].extend([yV4[i][idx], yV4[i][idx], None])
        yCr6_stretch[i].extend([yCr6[i][idx], yCr6[i][idx], None])
        yCr4_stretch[i].extend([yCr4[i][idx], yCr4[i][idx], None])

# Plot
fig, ax = plt.subplots(figsize=(7, 4)) 

solid_lines = []
dotted_lines = []

for i in range(col):
    solid_lines.append(ax.plot(x_stretch[i], y_stretch[i], linestyle='-', linewidth=2, c=colors[i], label="NiOOH")[0])
    dotted_lines.append(ax.plot(x_stretch[i], y4_stretch[i], linestyle=':', linewidth=2, c=colors[i], label="NiOOH")[0])
    #solid_lines.append(ax.plot(x_stretch[i], yFe6_stretch[i], linestyle='-', linewidth=2, c=colors[3], label="Ni$_{0.75}$Fe$_{0.25}$OOH")[0])
    #dotted_lines.append(ax.plot(x_stretch[i], yFe4_stretch[i], linestyle=':', linewidth=2, c=colors[3], label="Ni$_{0.75}$Fe$_{0.25}$OOH")[0])
    #solid_lines.append(ax.plot(x_stretch[i], yMn6_stretch[i], linestyle='-', linewidth=2, c=colors[4], label="Ni$_{0.75}$Mn$_{0.25}$OOH")[0])
    #dotted_lines.append(ax.plot(x_stretch[i], yMn4_stretch[i], linestyle=':', linewidth=2, c=colors[4], label="Ni$_{0.75}$Mn$_{0.25}$OOH")[0])
    #solid_lines.append(ax.plot(x_stretch[i], yV6_stretch[i], linestyle='-', linewidth=2, c=colors[6], label="Ni$_{0.75}$V$_{0.25}$OOH")[0])
    #dotted_lines.append(ax.plot(x_stretch[i], yV4_stretch[i], linestyle=':', linewidth=2, c=colors[6], label="Ni$_{0.75}$V$_{0.25}$OOH")[0])
    solid_lines.append(ax.plot(x_stretch[i], yCr6_stretch[i], linestyle='-', linewidth=2, c=colors[5], label="Ni$_{0.75}$Cr$_{0.25}$OOH")[0])
    dotted_lines.append(ax.plot(x_stretch[i], yCr4_stretch[i], linestyle=':', linewidth=2, c=colors[5], label="Ni$_{0.75}$Cr$_{0.25}$OOH")[0])


ax.set_ylabel('$\Delta$G (eV)')
ax.set_xlabel('Hydrogen coverage (%)')
ax.set_xticks([v * 100 for v in x[0]])  # Les positions des ticks
ax.set_xticklabels(text[0])  # Les labels correspondant aux ticks

# Créer deux légendes à droite du graphique
legend1 = ax.legend(handles=solid_lines, title="1.5 V vs RHE", loc="center left", bbox_to_anchor=(1.05, 0.75))
ax.add_artist(legend1)  # Ajoute la première légende au graphique
ax.legend(handles=dotted_lines, title="1.3 V vs RHE", loc="center left", bbox_to_anchor=(1.05, 0.5))

plt.tight_layout()  # Ajuste l'espace pour éviter les chevauchements


plt.savefig('/Users/ltreps/Downloads/Cr.pdf', bbox_inches='tight', pad_inches=0.1, dpi=300)
plt.show()
